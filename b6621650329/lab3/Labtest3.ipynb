# %%
import pandas as pd

# %%
s1 = pd.Series([5,20,30,35,60])

# %%
s1
# Out:
# 0     5
# 1    20
# 2    30
# 3    35
# 4    60
# dtype: int64

# %%
s2 = pd.Series([5,20,30,35,60],index='a b c d e'.split())

# %%
s2
# Out:
# a     5
# b    20
# c    30
# d    35
# e    60
# dtype: int64

# %%
s2['a']
# Out:
# 5

# %%
s1[4]
# Out:
# 60

# %%
s2[:'b']
# Out:
# a     5
# b    20
# dtype: int64

# %%
s2['b':]
# Out:
# b    20
# c    30
# d    35
# e    60
# dtype: int64

# %%
for index , value in s2.items():
    print(index,value)
# Out:
# a 5
# b 20
# c 30
# d 35
# e 60

# %%
s2.sum()
# Out:
# 150

# %%
s2.max()
# Out:
# 60

# %%
s2.min()
# Out:
# 5

# %%
s2.mean()
# Out:
# 30.0

# %%
import numpy as np

# %%
np.random.seed(1)
df = pd.DataFrame(np.random.randint(1,100,[5,4]),
                 index = 'a b c d e'.split(),
                 columns = 'w x y age'.split())

# %%
df
# Out:
#     w   x   y  age
# a  38  13  73   10
# b  76   6  80   65
# c  17   2  77   72
# d   7  26  51   21
# e  19  85  12   29

# %%
df['w']
# Out:
# a    38
# b    76
# c    17
# d     7
# e    19
# Name: w, dtype: int32

# %%
df.loc['a']
# Out:
# w    38
# x    13
# y    73
# z    10
# Name: a, dtype: int32

# %%
df.w
# Out:
# a    38
# b    76
# c    17
# d     7
# e    19
# Name: w, dtype: int32

# %%
df.iloc[0]
# Out:
# w    38
# x    13
# y    73
# z    10
# Name: a, dtype: int32

# %%
df[['w','x']]
# Out:
#     w   x
# a  38  13
# b  76   6
# c  17   2
# d   7  26
# e  19  85

# %%
df.loc[['a','e']]
# Out:
#     w   x   y   z
# a  38  13  73  10
# e  19  85  12  29

# %%
df['c':]
# Out:
#     w   x   y   z
# c  17   2  77  72
# d   7  26  51  21
# e  19  85  12  29

# %%
df.loc['a':'c' , ['w','x','z']]
# Out:
#     w   x   z
# a  38  13  10
# b  76   6  65
# c  17   2  72

# %%
df
# Out:
#     w   x   y   z
# a  38  13  73  10
# b  76   6  80  65
# c  17   2  77  72
# d   7  26  51  21
# e  19  85  12  29

# %%
for index , row in df.iterrows() :
    for i , value in row.items() :
        print(value)
# Out:
# 38
# 13
# 73
# 10
# 76
# 6
# 80
# 65
# 17
# 2
# 77
# 72
# 7
# 26
# 51
# 21
# 19
# 85
# 12
# 29

# %%
df.columns
# Out:
# Index(['w', 'x', 'y', 'z'], dtype='object')

# %%
df.rpow
# Out:
# <bound method DataFrame.rpow of     w   x   y   z
# a  38  13  73  10
# b  76   6  80  65
# c  17   2  77  72
# d   7  26  51  21
# e  19  85  12  29>

# %%
df>50
# Out:
#        w      x      y      z
# a  False  False   True  False
# b   True  False   True   True
# c  False  False   True   True
# d  False  False   True  False
# e  False   True  False  False

# %%
df[df>50]
# Out:
#       w     x     y   age
# a   NaN   NaN  73.0   NaN
# b  76.0   NaN  80.0  65.0
# c   NaN   NaN  77.0  72.0
# d   NaN   NaN  51.0   NaN
# e   NaN  85.0   NaN   NaN

# %%
df[df['age']>50].loc['b']
# Out:
# w      76
# x       6
# y      80
# age    65
# Name: b, dtype: int32

# %%
df
# Out:
#     w   x   y  age
# a  38  13  73   10
# b  76   6  80   65
# c  17   2  77   72
# d   7  26  51   21
# e  19  85  12   29

# %%
df = pd.read_csv('lab4 Sample - Superstore.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head(7)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.iloc[0]
# Out:
# Row ID                                           1
# Order ID                            CA-2016-152156
# Order Date                               11/8/2016
# Ship Date                               11/11/2016
# Ship Mode                             Second Class
# Customer ID                               CG-12520
# Customer Name                          Claire Gute
# Segment                                   Consumer
# Country                              United States
# City                                     Henderson
# State                                     Kentucky
# Postal Code                                  42420
# Region                                       South
# Product ID                         FUR-BO-10001798
# Category                                 Furniture
# Sub-Category                             Bookcases
# Product Name     Bush Somerset Collection Bookcase
# Sales                                       261.96
# ...

# %%
df.groupby('Ship Mode').sum()
# Out:
#                   Row ID                                           Order ID  \
# Ship Mode
# First Class      7498535  CA-2016-117590CA-2016-117590CA-2016-118255CA-2...
# Same Day         2784998  CA-2016-155516CA-2016-155516CA-2016-155516CA-2...
# Second Class     9601997  CA-2016-152156CA-2016-152156CA-2016-138688CA-2...
# Standard Class  30059485  US-2015-108966US-2015-108966CA-2014-115812CA-2...
#
#                                                        Order Date  \
# Ship Mode
# First Class     12/8/201612/8/20163/11/20163/11/20166/17/20166...
# Same Day        10/21/201610/21/201610/21/201610/21/20169/19/2...
# Second Class    11/8/201611/8/20166/12/20165/13/20148/27/20148...
# Standard Class  10/11/201510/11/20156/9/20146/9/20146/9/20146/...
#
#                                                         Ship Date  \
# Ship Mode
# First Class     12/10/201612/10/20163/13/20163/13/20166/18/201...
# Same Day        10/21/201610/21/201610/21/201610/21/20169/19/2...
# ...

# %%
df.groupby('Ship Mode')['Quantity'].describe()
# Out:
#                  count      mean       std  min  25%  50%  75%   max
# Ship Mode
# First Class     1538.0  3.701560  2.119098  1.0  2.0  3.0  5.0  14.0
# Same Day         543.0  3.609576  2.129233  1.0  2.0  3.0  5.0  14.0
# Second Class    1945.0  3.816452  2.263673  1.0  2.0  3.0  5.0  14.0
# Standard Class  5968.0  3.819873  2.246699  1.0  2.0  3.0  5.0  14.0

# %%
df['Sales'].max()
# Out:
# 22638.48

# %%
df['Sales']==df['Sales'].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Sales, Length: 9994, dtype: bool

# %%
df[df['Sales']==df['Sales'].max() ]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  3/18/2014  3/23/2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
#
#      Postal Code  Region       Product ID    Category Sub-Category  \
# 2697       32216   South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784
#
# [1 rows x 21 columns]

# %%
def fn(x) :
    return x**2

# %%
fn(5)
# Out:
# 25

# %%
df['Sales'].apply(fn)
# Out:
# 0        68623.041600
# 1       535736.163600
# 2          213.744400
# 3       916954.668506
# 4          500.327424
#             ...
# 9989       637.461504
# 9990      8456.641600
# 9991     66861.547776
# 9992       876.160000
# 9993     59126.785600
# Name: Sales, Length: 9994, dtype: float64

# %%
fn = lambda x:x**2

# %%
df['Sales'].apply(lambda x:x/10)
# Out:
# 0       26.19600
# 1       73.19400
# 2        1.46200
# 3       95.75775
# 4        2.23680
#           ...
# 9989     2.52480
# 9990     9.19600
# 9991    25.85760
# 9992     2.96000
# 9993    24.31600
# Name: Sales, Length: 9994, dtype: float64

# %%
df['Sales'].apply(lambda x:x*10 if x>0 else x/10)
# Out:
# 0       2619.600
# 1       7319.400
# 2        146.200
# 3       9575.775
# 4        223.680
#           ...
# 9989     252.480
# 9990     919.600
# 9991    2585.760
# 9992     296.000
# 9993    2431.600
# Name: Sales, Length: 9994, dtype: float64

# %%
df[df['Sales'].apply(lambda x: (x - np.floor(x)) == 0)]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 47        48  CA-2016-169194   6/20/2016   6/25/2016  Standard Class
# 59        60  CA-2016-111682   6/17/2016   6/18/2016     First Class
# 184      185  CA-2014-158274  11/19/2014  11/24/2014    Second Class
# 215      216  CA-2015-146262    1/2/2015    1/9/2015  Standard Class
# 320      321  CA-2014-164973   11/4/2014   11/9/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9633    9634  CA-2014-151330  10/14/2014  10/17/2014     First Class
# 9671    9672  US-2017-140312  11/13/2017  11/19/2017  Standard Class
# 9819    9820  CA-2015-162201    6/8/2015   6/12/2015  Standard Class
# 9834    9835  CA-2016-126627  10/10/2016  10/12/2016     First Class
# 9960    9961  CA-2017-141446   9/16/2017   9/18/2017    Second Class
#
#      Customer ID    Customer Name      Segment        Country  \
# 47      LH-16900   Lena Hernandez     Consumer  United States
# ...

# %%
df[df['Product Name'].apply(lambda x: 'collection' in x.lower() )]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 95        96  US-2017-109484   11/6/2017  11/12/2017  Standard Class
# 231      232  US-2017-100930    4/7/2017   4/12/2017  Standard Class
# 272      273  CA-2015-155334   7/30/2015   7/31/2015     First Class
# 292      293  CA-2016-110772  11/20/2016  11/24/2016    Second Class
# ...      ...             ...         ...         ...             ...
# 9334    9335  CA-2017-110198    5/1/2017    5/2/2017     First Class
# 9484    9485  CA-2016-164770   12/2/2016   12/4/2016    Second Class
# 9637    9638  CA-2014-124702  11/18/2014  11/25/2014  Standard Class
# 9857    9858  CA-2015-164301   3/26/2015   3/30/2015  Standard Class
# 9962    9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 0       CG-12520         Claire Gute     Consumer  United States
# ...

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Category'].nunique()
# Out:
# 3

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
    df.groupby('Category')['City'].count().sort_values(ascending = False)
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: City, dtype: int64
